# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import mnist
from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %%
train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

# Normalize the images.
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# Flatten the images.
train_images = train_images.reshape((-1, 784))
test_images = test_images.reshape((-1, 784))

# %%
# Build the model.
model = Sequential([
  Dense(64, activation='relu', input_shape=(784,)),
  Dense(64, activation='relu'),
  Dense(10, activation='softmax'),
])
# Out:
# 2022-11-22 11:15:07.199797: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
# Compile the model.
model.compile(
  optimizer='adam',
  loss='categorical_crossentropy',
  metrics=['accuracy'],
)

# %%
# Train the model.
model.fit(
  train_images,
  to_categorical(train_labels),
  epochs=5,
  batch_size=32,
)
# Out:
# 2022-11-22 11:15:07.718820: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3708 - accuracy: 0.8895
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1896 - accuracy: 0.9434
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1461 - accuracy: 0.9553
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1253 - accuracy: 0.9614
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1090 - accuracy: 0.9663

# %%
# Evaluate the model.
model.evaluate(
  test_images,
  to_categorical(test_labels)
)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1106 - accuracy: 0.9639
# [0.11061975359916687, 0.9639000296592712]

# %%
# Save the model to disk.
model.save_weights('model.h5')

# %%
# Predict on the first 5 test images.
predictions = model.predict(test_images[:5])

# Print our model's predictions.
print(np.argmax(predictions, axis=1)) # [7, 2, 1, 0, 4]

# Check our predictions against the ground truths.
print(test_labels[:5]) # [7, 2, 1, 0, 4]
# Out:
# [7 2 1 0 4]
# [7 2 1 0 4]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                650
# =================================================================
# Total params: 55,050
# Trainable params: 55,050
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Домашнее задание:
#
#
# 1. Попробуйте обучить, нейронную сеть на Keras(рассмотренную на уроке) на датасете MNIST с другими параметрами. Опишите в комментарии к уроку - какой результата вы добились от нейросети? Что помогло вам улучшить ее точность?
#
# 2. Поработайте с документацией Keras. Попробуйте найти полезные команды Keras неразобранные на уроке.

# %%
def train_model(model, epochs, batch_size):
    model.fit(
        train_images,
        to_categorical(train_labels),
        epochs=epochs,
        batch_size=batch_size
    )

# %%
epochs_list = [5, 10, 15, 20]
batch_list = [16, 32, 64, 128, 256]

# %%
for epochs in epochs_list:
    for batch_size in batch_list:
        model = Sequential([
            Dense(64, activation='relu', input_shape=(784,)),
            Dense(64, activation='relu'),
            Dense(10, activation='softmax')
        ])
        
        model.compile(
            optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )
        
        train_model(model, epochs, batch_size)
        print('*' * 100)
        model.evaluate(test_images, to_categorical(test_labels))
        print('*' * 100)
# Out:
# Epoch 1/5
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.3295 - accuracy: 0.8990
# Epoch 2/5
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.1726 - accuracy: 0.9473
# Epoch 3/5
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.1345 - accuracy: 0.9581
# Epoch 4/5
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1162 - accuracy: 0.9640
# Epoch 5/5
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1031 - accuracy: 0.9677
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1086 - accuracy: 0.9686
# ****************************************************************************************************
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3492 - accuracy: 0.8961
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1804 - accuracy: 0.9456
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1400 - accuracy: 0.9573
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1192 - accuracy: 0.9628
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1024 - accuracy: 0.9674
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1172 - accuracy: 0.9655
# ****************************************************************************************************
# Epoch 1/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3951 - accuracy: 0.8838
# Epoch 2/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2023 - accuracy: 0.9392
# Epoch 3/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1549 - accuracy: 0.9528
# Epoch 4/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1289 - accuracy: 0.9603
# Epoch 5/5
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1110 - accuracy: 0.9660
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1283 - accuracy: 0.9605
# ****************************************************************************************************
# Epoch 1/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4637 - accuracy: 0.8645
# Epoch 2/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.2282 - accuracy: 0.9328
# Epoch 3/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1757 - accuracy: 0.9470
# Epoch 4/5
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1466 - accuracy: 0.9556
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1274 - accuracy: 0.9618
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1232 - accuracy: 0.9619
# ****************************************************************************************************
# Epoch 1/5
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5721 - accuracy: 0.8350
# Epoch 2/5
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2770 - accuracy: 0.9191
# Epoch 3/5
# 235/235 [==============================] - 1s 4ms/step - loss: 0.2171 - accuracy: 0.9364
# Epoch 4/5
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1817 - accuracy: 0.9459
# Epoch 5/5
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1572 - accuracy: 0.9535
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1587 - accuracy: 0.9503
# ****************************************************************************************************
# Epoch 1/10
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.3394 - accuracy: 0.8954
# Epoch 2/10
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1772 - accuracy: 0.9445
# Epoch 3/10
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1379 - accuracy: 0.9572
# Epoch 4/10
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.1168 - accuracy: 0.9635
# Epoch 5/10
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.1030 - accuracy: 0.9671
# Epoch 6/10
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0944 - accuracy: 0.9705
# Epoch 7/10
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.0843 - accuracy: 0.9733
# Epoch 8/10
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.0799 - accuracy: 0.9744
# Epoch 9/10
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.0721 - accuracy: 0.9763
# Epoch 10/10
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.0686 - accuracy: 0.9782
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1005 - accuracy: 0.9698
# ****************************************************************************************************
# Epoch 1/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3510 - accuracy: 0.8952
# Epoch 2/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1878 - accuracy: 0.9428
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1460 - accuracy: 0.9554
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1245 - accuracy: 0.9620
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1063 - accuracy: 0.9665
# Epoch 6/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0966 - accuracy: 0.9697
# Epoch 7/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0888 - accuracy: 0.9714
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0789 - accuracy: 0.9742
# Epoch 9/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0748 - accuracy: 0.9758
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0691 - accuracy: 0.9780
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1208 - accuracy: 0.9666
# ****************************************************************************************************
# Epoch 1/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.4184 - accuracy: 0.8784
# Epoch 2/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.2063 - accuracy: 0.9380
# Epoch 3/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1591 - accuracy: 0.9517
# Epoch 4/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1295 - accuracy: 0.9617
# Epoch 5/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1129 - accuracy: 0.9651
# Epoch 6/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1013 - accuracy: 0.9685
# Epoch 7/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0910 - accuracy: 0.9715
# Epoch 8/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0830 - accuracy: 0.9748
# Epoch 9/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0755 - accuracy: 0.9764
# Epoch 10/10
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0721 - accuracy: 0.9775
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0949 - accuracy: 0.9720
# ****************************************************************************************************
# Epoch 1/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4490 - accuracy: 0.8691
# Epoch 2/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2306 - accuracy: 0.9313
# Epoch 3/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1799 - accuracy: 0.9456
# Epoch 4/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1473 - accuracy: 0.9566
# Epoch 5/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1281 - accuracy: 0.9619
# Epoch 6/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1145 - accuracy: 0.9653
# Epoch 7/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1024 - accuracy: 0.9684
# Epoch 8/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0925 - accuracy: 0.9716
# Epoch 9/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0851 - accuracy: 0.9738
# Epoch 10/10
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0790 - accuracy: 0.9753
# ****************************************************************************************************
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0974 - accuracy: 0.9691
# ****************************************************************************************************
# Epoch 1/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5791 - accuracy: 0.8374
# Epoch 2/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2686 - accuracy: 0.9216
# Epoch 3/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2140 - accuracy: 0.9367
# Epoch 4/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1777 - accuracy: 0.9480
# Epoch 5/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1500 - accuracy: 0.9546
# Epoch 6/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1344 - accuracy: 0.9597
# Epoch 7/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1210 - accuracy: 0.9640
# Epoch 8/10
# 235/235 [==============================] - 1s 4ms/step - loss: 0.1121 - accuracy: 0.9664
# Epoch 9/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0996 - accuracy: 0.9693
# Epoch 10/10
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0950 - accuracy: 0.9711
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1080 - accuracy: 0.9664
# ****************************************************************************************************
# Epoch 1/15
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.3341 - accuracy: 0.8983
# Epoch 2/15
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.1762 - accuracy: 0.9461
# Epoch 3/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1381 - accuracy: 0.9576
# Epoch 4/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1187 - accuracy: 0.9630
# Epoch 5/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1027 - accuracy: 0.9682
# Epoch 6/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0961 - accuracy: 0.9697
# Epoch 7/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0872 - accuracy: 0.9724
# Epoch 8/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0792 - accuracy: 0.9751
# Epoch 9/15
# 3750/3750 [==============================] - 9s 3ms/step - loss: 0.0769 - accuracy: 0.9757
# Epoch 10/15
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.0700 - accuracy: 0.9774
# Epoch 11/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0702 - accuracy: 0.9778
# Epoch 12/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0647 - accuracy: 0.9789
# Epoch 13/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0618 - accuracy: 0.9798
# Epoch 14/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0611 - accuracy: 0.9797
# Epoch 15/15
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0571 - accuracy: 0.9815
# ****************************************************************************************************
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1234 - accuracy: 0.9709
# ****************************************************************************************************
# Epoch 1/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3646 - accuracy: 0.8903
# Epoch 2/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1894 - accuracy: 0.9423
# Epoch 3/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1450 - accuracy: 0.9556
# Epoch 4/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1221 - accuracy: 0.9626
# Epoch 5/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1078 - accuracy: 0.9671
# Epoch 6/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0975 - accuracy: 0.9695
# Epoch 7/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0895 - accuracy: 0.9717
# Epoch 8/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0818 - accuracy: 0.9738
# Epoch 9/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0764 - accuracy: 0.9753
# Epoch 10/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0730 - accuracy: 0.9766
# Epoch 11/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 12/15
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0615 - accuracy: 0.9805
# Epoch 13/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0597 - accuracy: 0.9804
# Epoch 14/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0556 - accuracy: 0.9816
# Epoch 15/15
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0524 - accuracy: 0.9823
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1082 - accuracy: 0.9714
# ****************************************************************************************************
# Epoch 1/15
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3915 - accuracy: 0.8834
# Epoch 2/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.2027 - accuracy: 0.9388
# Epoch 3/15
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1526 - accuracy: 0.9535
# Epoch 4/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1289 - accuracy: 0.9602
# Epoch 5/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1132 - accuracy: 0.9652
# Epoch 6/15
# 938/938 [==============================] - 3s 3ms/step - loss: 0.1012 - accuracy: 0.9675
# Epoch 7/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0894 - accuracy: 0.9722
# Epoch 8/15
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0835 - accuracy: 0.9740
# Epoch 9/15
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0750 - accuracy: 0.9755
# Epoch 10/15
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0685 - accuracy: 0.9775
# Epoch 11/15
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0655 - accuracy: 0.9788
# Epoch 12/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0596 - accuracy: 0.9809
# Epoch 13/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0560 - accuracy: 0.9817
# Epoch 14/15
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0553 - accuracy: 0.9817
# Epoch 15/15
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0515 - accuracy: 0.9829
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1101 - accuracy: 0.9696
# ****************************************************************************************************
# Epoch 1/15
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4708 - accuracy: 0.8637
# Epoch 2/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2315 - accuracy: 0.9318
# Epoch 3/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1777 - accuracy: 0.9476
# Epoch 4/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1463 - accuracy: 0.9562
# Epoch 5/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1286 - accuracy: 0.9613
# Epoch 6/15
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1131 - accuracy: 0.9661
# Epoch 7/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1006 - accuracy: 0.9693
# Epoch 8/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0910 - accuracy: 0.9718
# Epoch 9/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0859 - accuracy: 0.9734
# Epoch 10/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0772 - accuracy: 0.9758
# Epoch 11/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0735 - accuracy: 0.9767
# Epoch 12/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0685 - accuracy: 0.9782
# Epoch 13/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0622 - accuracy: 0.9801
# Epoch 14/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0584 - accuracy: 0.9815
# Epoch 15/15
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0546 - accuracy: 0.9823
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0875 - accuracy: 0.9728
# ****************************************************************************************************
# Epoch 1/15
# 235/235 [==============================] - 1s 4ms/step - loss: 0.5481 - accuracy: 0.8429
# Epoch 2/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2582 - accuracy: 0.9248
# Epoch 3/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1994 - accuracy: 0.9421
# Epoch 4/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1619 - accuracy: 0.9525
# Epoch 5/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1388 - accuracy: 0.9584
# Epoch 6/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1211 - accuracy: 0.9647
# Epoch 7/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1083 - accuracy: 0.9676
# Epoch 8/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0972 - accuracy: 0.9712
# Epoch 9/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0901 - accuracy: 0.9719
# Epoch 10/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0857 - accuracy: 0.9738
# Epoch 11/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0770 - accuracy: 0.9764
# Epoch 12/15
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0701 - accuracy: 0.9786
# Epoch 13/15
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0645 - accuracy: 0.9801
# Epoch 14/15
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0623 - accuracy: 0.9806
# Epoch 15/15
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0590 - accuracy: 0.9816
# ****************************************************************************************************
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0896 - accuracy: 0.9727
# ****************************************************************************************************
# Epoch 1/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.3310 - accuracy: 0.8984
# Epoch 2/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1728 - accuracy: 0.9461
# Epoch 3/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1391 - accuracy: 0.9569
# Epoch 4/20
# 3750/3750 [==============================] - 10s 3ms/step - loss: 0.1192 - accuracy: 0.9625
# Epoch 5/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.1057 - accuracy: 0.9661
# Epoch 6/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0973 - accuracy: 0.9694
# Epoch 7/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0878 - accuracy: 0.9722
# Epoch 8/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0805 - accuracy: 0.9742
# Epoch 9/20
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.0763 - accuracy: 0.9757
# Epoch 10/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0716 - accuracy: 0.9763
# Epoch 11/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0653 - accuracy: 0.9789
# Epoch 12/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0641 - accuracy: 0.9786
# Epoch 13/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0634 - accuracy: 0.9800
# Epoch 14/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0564 - accuracy: 0.9808
# Epoch 15/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0547 - accuracy: 0.9821
# Epoch 16/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0522 - accuracy: 0.9831
# Epoch 17/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0533 - accuracy: 0.9824
# Epoch 18/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0512 - accuracy: 0.9831
# Epoch 19/20
# 3750/3750 [==============================] - 9s 2ms/step - loss: 0.0472 - accuracy: 0.9839
# Epoch 20/20
# 3750/3750 [==============================] - 8s 2ms/step - loss: 0.0472 - accuracy: 0.9843
# ****************************************************************************************************
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1407 - accuracy: 0.9655
# ****************************************************************************************************
# Epoch 1/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3631 - accuracy: 0.8926
# Epoch 2/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1880 - accuracy: 0.9440
# Epoch 3/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1436 - accuracy: 0.9560
# Epoch 4/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1183 - accuracy: 0.9625
# Epoch 5/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1030 - accuracy: 0.9680
# Epoch 6/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0922 - accuracy: 0.9711
# Epoch 7/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0821 - accuracy: 0.9742
# Epoch 8/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0753 - accuracy: 0.9758
# Epoch 9/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0706 - accuracy: 0.9775
# Epoch 10/20
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0641 - accuracy: 0.9791
# Epoch 11/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0616 - accuracy: 0.9798
# Epoch 12/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0571 - accuracy: 0.9815
# Epoch 13/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0521 - accuracy: 0.9827
# Epoch 14/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0507 - accuracy: 0.9833
# Epoch 15/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0489 - accuracy: 0.9836
# Epoch 16/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0460 - accuracy: 0.9848
# Epoch 17/20
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0418 - accuracy: 0.9858
# Epoch 18/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0421 - accuracy: 0.9863
# Epoch 19/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0378 - accuracy: 0.9868
# Epoch 20/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0390 - accuracy: 0.9867
# ****************************************************************************************************
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1241 - accuracy: 0.9681
# ****************************************************************************************************
# Epoch 1/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.3995 - accuracy: 0.8816
# Epoch 2/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.2111 - accuracy: 0.9380
# Epoch 3/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1610 - accuracy: 0.9524
# Epoch 4/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1310 - accuracy: 0.9610
# Epoch 5/20
# 938/938 [==============================] - 2s 2ms/step - loss: 0.1156 - accuracy: 0.9645
# Epoch 6/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.1009 - accuracy: 0.9683
# Epoch 7/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0912 - accuracy: 0.9719
# Epoch 8/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0837 - accuracy: 0.9735
# Epoch 9/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0773 - accuracy: 0.9765
# Epoch 10/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0720 - accuracy: 0.9775
# Epoch 11/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0656 - accuracy: 0.9796
# Epoch 12/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0611 - accuracy: 0.9801
# Epoch 13/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0586 - accuracy: 0.9812
# Epoch 14/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0553 - accuracy: 0.9823
# Epoch 15/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0527 - accuracy: 0.9826
# Epoch 16/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0489 - accuracy: 0.9838
# Epoch 17/20
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0446 - accuracy: 0.9854
# Epoch 18/20
# 938/938 [==============================] - 2s 3ms/step - loss: 0.0455 - accuracy: 0.9845
# Epoch 19/20
# 938/938 [==============================] - 2s 2ms/step - loss: 0.0403 - accuracy: 0.9865
# Epoch 20/20
# 938/938 [==============================] - 3s 3ms/step - loss: 0.0382 - accuracy: 0.9872
# ****************************************************************************************************
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1166 - accuracy: 0.9697
# ****************************************************************************************************
# Epoch 1/20
# 469/469 [==============================] - 2s 3ms/step - loss: 0.4679 - accuracy: 0.8637
# Epoch 2/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.2396 - accuracy: 0.9294
# Epoch 3/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1850 - accuracy: 0.9452
# Epoch 4/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1518 - accuracy: 0.9540
# Epoch 5/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1317 - accuracy: 0.9601
# Epoch 6/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1149 - accuracy: 0.9653
# Epoch 7/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.1022 - accuracy: 0.9689
# Epoch 8/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0928 - accuracy: 0.9718
# Epoch 9/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0849 - accuracy: 0.9739
# Epoch 10/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0783 - accuracy: 0.9757
# Epoch 11/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0718 - accuracy: 0.9778
# Epoch 12/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0690 - accuracy: 0.9779
# Epoch 13/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0643 - accuracy: 0.9800
# Epoch 14/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0584 - accuracy: 0.9817
# Epoch 15/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0555 - accuracy: 0.9824
# Epoch 16/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0530 - accuracy: 0.9834
# Epoch 17/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0501 - accuracy: 0.9834
# Epoch 18/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0490 - accuracy: 0.9840
# Epoch 19/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0444 - accuracy: 0.9856
# Epoch 20/20
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0428 - accuracy: 0.9860
# ****************************************************************************************************
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0964 - accuracy: 0.9719
# ****************************************************************************************************
# Epoch 1/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.5672 - accuracy: 0.8388
# Epoch 2/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2709 - accuracy: 0.9217
# Epoch 3/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.2225 - accuracy: 0.9340
# Epoch 4/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1841 - accuracy: 0.9457
# Epoch 5/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1624 - accuracy: 0.9524
# Epoch 6/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1417 - accuracy: 0.9584
# Epoch 7/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1283 - accuracy: 0.9617
# Epoch 8/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1167 - accuracy: 0.9647
# Epoch 9/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.1070 - accuracy: 0.9682
# Epoch 10/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0977 - accuracy: 0.9707
# Epoch 11/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0915 - accuracy: 0.9719
# Epoch 12/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0857 - accuracy: 0.9740
# Epoch 13/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0787 - accuracy: 0.9758
# Epoch 14/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0733 - accuracy: 0.9776
# Epoch 15/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0689 - accuracy: 0.9789
# Epoch 16/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0664 - accuracy: 0.9791
# Epoch 17/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0630 - accuracy: 0.9797
# Epoch 18/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0591 - accuracy: 0.9812
# Epoch 19/20
# 235/235 [==============================] - 1s 3ms/step - loss: 0.0563 - accuracy: 0.9826
# Epoch 20/20
# 235/235 [==============================] - 1s 4ms/step - loss: 0.0528 - accuracy: 0.9834
# ****************************************************************************************************
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1006 - accuracy: 0.9699
# ****************************************************************************************************

# %% [markdown]
# ### Вывод:
#
# Самая высокая точность во время обучения модели (fit model) наблюдается при 20 эпохах (на 19-ю эпоху) и 32 батчах: 0.9864. Последняя 20-я эпоха снизила точность до 0.9861 (такое наблюдается до 64 батчей включительно; при 128 батчах качество 20-й эпохи выше, чем у 19-й).
#
# При этом, при оценивании модели (evaluate model), самая высокая точность так же при 20 эпохах, но количество батчей либо 128, либо 256, а сам показатель точности: 0.9748.
